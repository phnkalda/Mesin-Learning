# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/healthcare-dataset-stroke-data - healthcare-dataset-stroke-data.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
print("---DATA SET AWAL---")
print(df.isnull().sum())
# Out:
# ---DATA SET AWAL---
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df['bmi'].fillna(df['bmi'].median(), inplace=True)
# Out:
# /tmp/ipykernel_12431/1439978410.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(df['bmi'].median(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])

# %%
df = pd.get_dummies(df, columns=['stroke'], prefix='stroke')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046       1  67.0             0              1          Yes
# 1     51676       0  61.0             0              0          Yes
# 2     31112       1  80.0             0              1          Yes
# 3     60182       0  49.0             0              0          Yes
# 4      1665       0  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234       0  80.0             1              0          Yes
# 5106  44873       0  81.0             0              0          Yes
# 5107  19723       0  35.0             0              0          Yes
# 5108  37544       1  51.0             0              0          Yes
# 5109  44679       0  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
print(df.isnull().sum())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke_0             0
# stroke_1             0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke_0', 'stroke_1'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['gender_scaled'] = scaler.fit_transform(df[['gender']])

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046       1  67.0             0              1          Yes
# 1     51676       0  61.0             0              0          Yes
# 2     31112       1  80.0             0              1          Yes
# 3     60182       0  49.0             0              0          Yes
# 4      1665       0  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234       0  80.0             1              0          Yes
# 5106  44873       0  81.0             0              0          Yes
# 5107  19723       0  35.0             0              0          Yes
# 5108  37544       1  51.0             0              0          Yes
# 5109  44679       0  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
import matplotlib.pyplot as plt
# Sebelum preprocessing
plt.hist(df['gender'], bins=20, color='blue', alpha=0.5)
# Sesudah preprocessing
plt.hist(df['gender_scaled'], bins=20, color='red', alpha=0.5)
plt.legend(['Sebelum', 'Sesudah'])
plt.show()

# %%
df = pd.read_csv ("/content/drive/MyDrive/Machine Learning/FuelConsumptionCo2.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
xdf = df[['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_COMB', 'CO2EMISSIONS']]
xdf.head(10)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267
# 9         2.4          4                   9.2           212

# %%
import matplotlib.pyplot as plt
viz = df[['CYLINDERS','ENGINESIZE', 'CO2EMISSIONS', 'FUELCONSUMPTION_COMB']]
viz.hist()
plt.show()

# %%
plt.scatter(df.FUELCONSUMPTION_COMB, df.CO2EMISSIONS, color='blue')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("emission")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = xdf[['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_COMB']]
y = xdf['CO2EMISSIONS']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
y_pred
# Out:
# array([302.95237705, 240.91489956, 272.50244127, 235.31017981,
#        204.07702562, 245.78307279, 304.87320139, 283.65078533,
#        309.17145244, 307.72944493, 287.73574015, 391.1248773 ,
#        252.78536659, 251.38779254, 262.02954829, 255.19611726,
#        210.0661428 , 250.60457413, 190.07243802, 307.77387839,
#        318.69226424, 205.64346244, 256.59369131, 248.86927454,
#        261.96845285, 197.07473182, 205.0291068 , 186.2641133 ,
#        309.06368511, 248.97704187, 390.77380382, 203.80039551,
#        205.64346244, 327.26099486, 238.16642335, 286.76699699,
#        277.01622698, 399.17367168, 199.31661972, 204.92133946,
#        176.7433015 , 187.21619448, 186.87846894, 209.68174536,
#        279.84246061, 199.59324982, 244.83099161, 259.11220931,
#        192.65205146, 362.85573398, 315.0061304 , 278.21492835,
#        211.69367506, 267.91089814, 264.82469639, 315.39052783,
#        388.70077869, 322.73054717, 191.69997028, 278.44488656,
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nMSE: {mse: .2f}")
print(f"RMSE: {rmse: .2f}")
print(f"R-squared: {r2: .2f}")
# Out:
# MSE:  512.86
# RMSE:  22.65
# R-squared:  0.88

# %%
print(f"Coefficients: {model.coef_}")
print(f"Intercept: {model.intercept_}")
# Out:
# Coefficients: [11.2094395   7.15561381  9.5208118 ]
# Intercept: 67.3483851836209

# %%
import matplotlib.pyplot as plt

plt.scatter(df.ENGINESIZE, df.CO2EMISSIONS, color='green')
plt.xlabel("Engine Size")
plt.ylabel("CO2 Emission")
plt.title("Engine Size vs. CO2 Emission")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(df.FUELCONSUMPTION_COMB, df.CO2EMISSIONS, color='blue')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("CO2 Emission")
plt.title("Fuel Consumption (Combined) vs. CO2 Emission")
plt.show()

# %%
plt.scatter(df.FUELCONSUMPTION_COMB, df.CO2EMISSIONS, color='blue')
plt.xlabel("'FUELCONSUMPTION_COMB', 'CYLINDERS', 'FUELCONSUMPTION_COMB'")
plt.ylabel("emission")
plt.show()

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/iris - iris.csv")
df
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
with open('/content/drive/MyDrive/Machine Learning/iris - iris.csv') as f:
    lines = f.readlines()

data = [line.strip().split(',') for line in lines[1:]]

df = pd.DataFrame(data, columns=['sepal_length', 'sepal_widht', 'petal_lenght', 'petal_widht', 'class'])
df = df.astype({
    'sepal_length':'float',
    'sepal_widht':'float',
    'petal_lenght':'float',
    'petal_widht':'float',
    'class':'int'
})

# %%
df
# Out:
#      sepal_length  sepal_widht  petal_lenght  petal_widht  class
# 0             5.1          3.5           1.4          0.2      0
# 1             4.9          3.0           1.4          0.2      0
# 2             4.7          3.2           1.3          0.2      0
# 3             4.6          3.1           1.5          0.2      0
# 4             5.0          3.6           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 145           6.7          3.0           5.2          2.3      2
# 146           6.3          2.5           5.0          1.9      2
# 147           6.5          3.0           5.2          2.0      2
# 148           6.2          3.4           5.4          2.3      2
# 149           5.9          3.0           5.1          1.8      2
#
# [150 rows x 5 columns]

# %%
x = df.iloc[: :-1].values # Semua kolom kecuali terakhir
y = df.iloc[:, -1].values #Kolom terakhir (class)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test,y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nAccuary:",accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Accuary: 1.0

# %%
from sklearn.naive_bayes import GaussianNB

nb_classifier = GaussianNB()
nb_classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb_classifier.predict(x_test)

print("Confusion Matrix (Naive Bayes):")
print(confusion_matrix(y_test, y_pred_nb))
print("\nClassification Report (Naive Bayes):")
print(classification_report(y_test, y_pred_nb))
print("\nAccuracy (Naive Bayes):", accuracy_score(y_test, y_pred_nb))
# Out:
# Confusion Matrix (Naive Bayes):
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#
# Classification Report (Naive Bayes):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Accuracy (Naive Bayes): 1.0

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_widht  petal_lenght  petal_widht       class
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/Wholesale customers data - Wholesale customers data.csv")
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

from google.colab import drive
drive.mount('/content/drive')

sns.set_style('whitegrid')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/Wholesale customers data - Wholesale customers data.csv")
print("Tampilkan 5 Baris Pertama Data:")
display(df.head())

print("\nInformasi Dataset:")
df.info()
# Out:
# Tampilkan 5 Baris Pertama Data:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
# ...

# %%
x = df.iloc[:, [3, 4]].values

plt.figure(figsize=(8,5))
plt.scatter(x[:,0], x[:,1], c='gray', s=50)
plt.title('Sebaran Data Pelanggan (Belum di klaster)', fontsize=14)
plt.xlabel('Pendapatan Tahunan (k$)')
plt.ylabel('Skor Pengeluaran (1-100)')
plt.show()

# %%
wcss = [] # Initialize wcss list
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--', color='b')
plt.title('Metode Elbow untuk menentukan jumlah klaster optimal', fontsize=14)
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('WCSS (inersia)')
plt.xticks(np.arange(1, 11, 1))

# Corrected plt.annotate line
plt.annotate('Titik siku optimal (k=5)', xy=(5, wcss[4]), xytext=(6, wcss[4] + 40000),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.show()

# %%
kmeans =KMeans(n_clusters=5, init='k-means++', random_state=42, n_init=10)
y_kmeans = kmeans.fit_predict(x)

plt.figure(figsize=(12, 8))

plt.scatter(x[y_kmeans == 0,0], x[y_kmeans == 0,1], s=100, c='red', label='klaster 1')
plt.scatter(x[y_kmeans == 1,0], x[y_kmeans == 1,1], s=100, c='blue', label='klaster 2')
plt.scatter(x[y_kmeans == 2,0], x[y_kmeans == 2,1], s=100, c='green', label='klaster 3')
plt.scatter(x[y_kmeans == 3,0], x[y_kmeans == 3,1], s=100, c='cyan', label='klaster 4')
plt.scatter(x[y_kmeans == 4,0], x[y_kmeans == 4,1], s=100, c='magenta', label='klaster 5')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='yellow', marker='*', edgecolor='black', label='centroid')

plt.title('Segmentasi Pelanggan Mall (K-Means Clusturing)', fontsize=16)
plt.xlabel('Pendapatan Tahunan (k$)')
plt.ylabel('Skor Pengeluaran (1-100)')
plt.legend()
plt.show()

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/Mall_Customers - Mall_Customers.csv")
print("Tampilkan 5 Baris Pertama Data:")
display(df.head())

print("\nInformasi Dataset:")
df.info()
# Out:
# Tampilkan 5 Baris Pertama Data:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# ...

# %%
x = df.iloc[:, [3, 4]].values

plt.figure(figsize=(8,5))
plt.scatter(x[:,0], x[:,1], c='gray', s=50)
plt.title('Sebaran Data Pelanggan (Belum di klaster)', fontsize=14)
plt.xlabel('Pendapatan Tahunan (k$)')
plt.ylabel('Skor Pengeluaran (1-100)')
plt.show()

# %%
wcss = [] # Initialize wcss list
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--', color='b')
plt.title('Metode Elbow untuk menentukan jumlah klaster optimal', fontsize=14)
plt.xlabel('Jumlah Klaster (k)')
plt.ylabel('WCSS (inersia)')
plt.xticks(np.arange(1, 11, 1))

# Corrected plt.annotate line
plt.annotate('Titik siku optimal (k=5)', xy=(5, wcss[4]), xytext=(6, wcss[4] + 40000),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.show()

# %%
kmeans =KMeans(n_clusters=5, init='k-means++', random_state=42, n_init=10)
y_kmeans = kmeans.fit_predict(x)

plt.figure(figsize=(12, 8))

plt.scatter(x[y_kmeans == 0,0], x[y_kmeans == 0,1], s=100, c='red', label='klaster 1')
plt.scatter(x[y_kmeans == 1,0], x[y_kmeans == 1,1], s=100, c='blue', label='klaster 2')
plt.scatter(x[y_kmeans == 2,0], x[y_kmeans == 2,1], s=100, c='green', label='klaster 3')
plt.scatter(x[y_kmeans == 3,0], x[y_kmeans == 3,1], s=100, c='cyan', label='klaster 4')
plt.scatter(x[y_kmeans == 4,0], x[y_kmeans == 4,1], s=100, c='magenta', label='klaster 5')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='yellow', marker='*', edgecolor='black', label='centroid')

plt.title('Segmentasi Pelanggan Mall (K-Means Clusturing)', fontsize=16)
plt.xlabel('Pendapatan Tahunan (k$)')
plt.ylabel('Skor Pengeluaran (1-100)')
plt.legend()
plt.show()
